# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("weatherAUS_clear.csv")
df
# Out:
#         Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall
# 0                0  2008-12-01   Albury     13.4     22.9       0.6  \
# 1                1  2008-12-02   Albury      7.4     25.1       0.0
# 2                2  2008-12-03   Albury     12.9     25.7       0.0
# 3                3  2008-12-04   Albury      9.2     28.0       0.0
# 4                4  2008-12-05   Albury     17.5     32.3       1.0
# ...            ...         ...      ...      ...      ...       ...
# 140782      145454  2017-06-20    Uluru      3.5     21.8       0.0
# 140783      145455  2017-06-21    Uluru      2.8     23.4       0.0
# 140784      145456  2017-06-22    Uluru      3.6     25.3       0.0
# 140785      145457  2017-06-23    Uluru      5.4     26.9       0.0
# 140786      145458  2017-06-24    Uluru      7.8     27.0       0.0
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am
# 0                W           44.0          W        WNW          20.0  \
# ...

# %%
df = df.drop(columns='Unnamed: 0')
df = df.drop(columns='Date')
df
# Out:
#        Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed
# 0        Albury     13.4     22.9       0.6           W           44.0  \
# 1        Albury      7.4     25.1       0.0         WNW           44.0
# 2        Albury     12.9     25.7       0.0         WSW           46.0
# 3        Albury      9.2     28.0       0.0          NE           24.0
# 4        Albury     17.5     32.3       1.0           W           41.0
# ...         ...      ...      ...       ...         ...            ...
# 140782    Uluru      3.5     21.8       0.0           E           31.0
# 140783    Uluru      2.8     23.4       0.0           E           31.0
# 140784    Uluru      3.6     25.3       0.0         NNW           22.0
# 140785    Uluru      5.4     26.9       0.0           N           37.0
# 140786    Uluru      7.8     27.0       0.0          SE           28.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

Oenc = OrdinalEncoder()
Oenc.fit(df[['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm']])
df
# Out:
#        Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed
# 0        Albury     13.4     22.9       0.6           W           44.0  \
# 1        Albury      7.4     25.1       0.0         WNW           44.0
# 2        Albury     12.9     25.7       0.0         WSW           46.0
# 3        Albury      9.2     28.0       0.0          NE           24.0
# 4        Albury     17.5     32.3       1.0           W           41.0
# ...         ...      ...      ...       ...         ...            ...
# 140782    Uluru      3.5     21.8       0.0           E           31.0
# 140783    Uluru      2.8     23.4       0.0           E           31.0
# 140784    Uluru      3.6     25.3       0.0         NNW           22.0
# 140785    Uluru      5.4     26.9       0.0           N           37.0
# 140786    Uluru      7.8     27.0       0.0          SE           28.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am
# ...

# %%
from
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py install for sklearn: started
#   Running setup.py install for sklearn: finished with status 'done'
# ...
#   DEPRECATION: sklearn is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\Haier\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
Lenc._classes

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
Onhot.categories_

# %%
Onhot.transform(df[['RainToday']]).toarray()

# %%
df[['RainTodayNo', 'RainTodayYes']] = Onhot.fit_transform(df[['RainToday']]).toarray()
df

# %%
from sklearn.preprocessing import Normalizer

Norm = Normalizer()

df[['Pressure9am', 'Pressure3pm']] = Norm.fit_transform(df[['Pressure9am', 'Pressure3pm']])
df
# Out:
#        Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed
# 0        Albury     13.4     22.9       0.6           W           44.0  \
# 1        Albury      7.4     25.1       0.0         WNW           44.0
# 2        Albury     12.9     25.7       0.0         WSW           46.0
# 3        Albury      9.2     28.0       0.0          NE           24.0
# 4        Albury     17.5     32.3       1.0           W           41.0
# ...         ...      ...      ...       ...         ...            ...
# 140782    Uluru      3.5     21.8       0.0           E           31.0
# 140783    Uluru      2.8     23.4       0.0           E           31.0
# 140784    Uluru      3.6     25.3       0.0         NNW           22.0
# 140785    Uluru      5.4     26.9       0.0           N           37.0
# 140786    Uluru      7.8     27.0       0.0          SE           28.0
#
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am
# ...

# %%
from sklearn.model_selection import train_test_split

Y = df['RainTomorrow']
X = df.drop(columns=['RainTomorrow'])

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
x_train
# Out:
#             Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed
# 119008         Perth     13.5     26.0       0.0          SW           33.0  \
# 68281        Mildura     16.0     30.0       0.0           N           43.0
# 42953     Wollongong     19.0     26.3       0.0          NE           41.0
# 91339     Townsville     14.7     27.2       0.0           E           50.0
# 26428       Richmond      5.7     15.5       0.0         ESE           11.0
# ...              ...      ...      ...       ...         ...            ...
# 110268   Witchcliffe     15.4     24.8       0.0         SSE           48.0
# 119879    SalmonGums      3.2     15.5       9.2         SSW           43.0
# 103694       Woomera     11.7     23.6       0.0          SE           37.0
# 131932  AliceSprings     20.2     34.5       0.0          SE           37.0
# 121958    SalmonGums     11.9     23.0       3.8         SSW           50.0
#
# ...
